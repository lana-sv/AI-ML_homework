# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import tensorflow as tf
import keras

from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
train = pd.read_csv('/Users/lana-n/datacsv/hrtrain.csv')
train
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# 2                sourcing                1   34                   3.0
# 3                   other                2   39                   1.0
# 4                   other                1   45                   3.0
# ...                   ...              ...  ...                   ...
# 54803            sourcing                1   48                   3.0
# 54804               other                1   37                   2.0
# 54805               other                1   27                   5.0
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  awards_won?  avg_training_score  is_promoted
# 0                      8            0                  49            0
# 1                      4            0                  60            0
# 2                      7            0                  50            0
# 3                     10            0                  50            0
# 4                      2            0                  73            0
# ...                  ...          ...                 ...          ...
# 54803                 17            0                  78            0
# 54804                  6            0                  56            0
# 54805                  3            0                  79            0
# 54806                  2            0                  45            0
# 54807                  5            0                  49            0
#
# [54808 rows x 13 columns]

# %%
test = pd.read_csv('/Users/lana-n/datacsv/hrtest.csv')
test
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   NaN
# 1                   other                1   31                   3.0
# 2                   other                1   31                   1.0
# 3                   other                3   31                   2.0
# 4                sourcing                1   30                   4.0
# ...                   ...              ...  ...                   ...
# 23485            sourcing                1   24                   3.0
# 23486            sourcing                1   31                   3.0
# 23487            sourcing                1   26                   4.0
# 23488            sourcing                3   27                   NaN
# 23489               other                3   40                   5.0
#
#        length_of_service  awards_won?  avg_training_score
# 0                      1            0                  77
# 1                      5            0                  51
# 2                      4            0                  47
# 3                      9            0                  65
# 4                      7            0                  61
# ...                  ...          ...                 ...
# 23485                  1            0                  61
# 23486                  7            0                  74
# 23487                  4            0                  50
# 23488                  1            0                  70
# 23489                  5            0                  89
#
# [23490 rows x 12 columns]

# %%
train.is_promoted.unique()
# Out:
# array([0, 1])

# %%
train.is_promoted.value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %%
train01 = train.loc[train['is_promoted'] == 1] 

train01
# Out:
#        employee_id         department     region         education gender  \
# 11           49017  Sales & Marketing   region_7        Bachelor's      f
# 39           58304  Sales & Marketing  region_28        Bachelor's      m
# 60           17673  Sales & Marketing   region_4  Master's & above      m
# 66           77981            Finance  region_22        Bachelor's      m
# 67           16502  Sales & Marketing  region_22        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54734        11685         Operations  region_15        Bachelor's      m
# 54757        14502         Technology   region_7  Master's & above      m
# 54761         8278        Procurement  region_13        Bachelor's      f
# 54792          994  Sales & Marketing  region_14        Bachelor's      m
# 54796        12592  Sales & Marketing  region_25  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 11               sourcing                1   35                   5.0
# 39               sourcing                1   33                   5.0
# 60                  other                1   50                   4.0
# 66                  other                1   27                   NaN
# 67               sourcing                1   27                   NaN
# ...                   ...              ...  ...                   ...
# 54734            sourcing                1   31                   NaN
# 54757               other                1   54                   4.0
# 54761            sourcing                1   30                   4.0
# 54792               other                1   59                   3.0
# 54796               other                1   34                   3.0
#
#        length_of_service  awards_won?  avg_training_score  is_promoted
# 11                     3            0                  50            1
# 39                     6            0                  51            1
# 60                    17            0                  47            1
# 66                     1            1                  58            1
# 67                     1            0                  61            1
# ...                  ...          ...                 ...          ...
# 54734                  1            0                  56            1
# 54757                  7            0                  81            1
# 54761                  2            0                  86            1
# 54792                 11            0                  65            1
# 54796                  7            0                  60            1
#
# [4668 rows x 13 columns]

# %%
train00 = train.loc[train['is_promoted'] == 0] 
train00
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# 2                sourcing                1   34                   3.0
# 3                   other                2   39                   1.0
# 4                   other                1   45                   3.0
# ...                   ...              ...  ...                   ...
# 54803            sourcing                1   48                   3.0
# 54804               other                1   37                   2.0
# 54805               other                1   27                   5.0
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  awards_won?  avg_training_score  is_promoted
# 0                      8            0                  49            0
# 1                      4            0                  60            0
# 2                      7            0                  50            0
# 3                     10            0                  50            0
# 4                      2            0                  73            0
# ...                  ...          ...                 ...          ...
# 54803                 17            0                  78            0
# 54804                  6            0                  56            0
# 54805                  3            0                  79            0
# 54806                  2            0                  45            0
# 54807                  5            0                  49            0
#
# [50140 rows x 13 columns]

# %%
subset00 = train00.sample(n=5000)

subset00
# Out:
#        employee_id         department     region         education gender  \
# 43982         3057  Sales & Marketing   region_7  Master's & above      m
# 44669        26295            Finance  region_29        Bachelor's      m
# 27046        16310  Sales & Marketing  region_15        Bachelor's      f
# 12451        23364         Technology   region_5        Bachelor's      m
# 28325        55642         Technology  region_27        Bachelor's      f
# ...            ...                ...        ...               ...    ...
# 7065         43472  Sales & Marketing   region_8  Master's & above      m
# 16689        39231  Sales & Marketing   region_2               NaN      m
# 17573        64131         Technology  region_25  Master's & above      f
# 39597        64285  Sales & Marketing   region_5        Bachelor's      m
# 3421         17931              Legal  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 43982               other                1   44                   3.0
# 44669            sourcing                1   28                   3.0
# 27046            sourcing                1   38                   3.0
# 12451               other                1   23                   NaN
# 28325               other                1   26                   4.0
# ...                   ...              ...  ...                   ...
# 7065                other                1   44                   1.0
# 16689               other                1   50                   4.0
# 17573               other                1   33                   5.0
# 39597               other                1   37                   3.0
# 3421                other                1   29                   3.0
#
#        length_of_service  awards_won?  avg_training_score  is_promoted
# 43982                  6            0                  51            0
# 44669                  2            0                  64            0
# 27046                  7            0                  49            0
# 12451                  1            0                  77            0
# 28325                  2            0                  79            0
# ...                  ...          ...                 ...          ...
# 7065                  14            0                  53            0
# 16689                  6            0                  50            0
# 17573                  4            0                  80            0
# 39597                  7            0                  50            0
# 3421                   3            0                  60            0
#
# [5000 rows x 13 columns]

# %%
train_balanced = pd.concat([subset00, train01], ignore_index=True)

# %%
train_balanced.shape
#test.shape
# Out:
# (9668, 13)

# %%
train_balanced.isnull().sum()
# Out:
# employee_id               0
# department                0
# region                    0
# education               356
# gender                    0
# recruitment_channel       0
# no_of_trainings           0
# age                       0
# previous_year_rating    719
# length_of_service         0
# awards_won?               0
# avg_training_score        0
# is_promoted               0
# dtype: int64

# %%
train = train_balanced

# %%
#test.isnull().sum()

# %%
# lets impute the missing values in the Training Data

train['education'] = train['education'].fillna(train['education'].mode()[0])
train['previous_year_rating'] = train['previous_year_rating'].fillna(train['previous_year_rating'].mode()[0])

# lets check whether the Null values are still present or not?
print("Number of Missing Values Left in the Training Data :", train.isnull().sum().sum())
# Out:
# Number of Missing Values Left in the Training Data : 0

# %%
# lets impute the missing values in the Testing Data

test['education'] = test['education'].fillna(test['education'].mode()[0])
test['previous_year_rating'] = test['previous_year_rating'].fillna(test['previous_year_rating'].mode()[0])

# lets check whether the Null values are still present or not?
print("Number of Missing Values Left in the Testing Data :", test.isnull().sum().sum())
# Out:
# Number of Missing Values Left in the Testing Data : 0

# %%
#test.isnull().sum()
#train.isnull().sum()

# %%
train.department.unique()   #9 unique values
# Out:
# array(['Sales & Marketing', 'Finance', 'Technology', 'HR', 'Procurement',
#        'Operations', 'Analytics', 'Legal', 'R&D'], dtype=object)

# %%
train['department'] = train['department'].map({'Sales & Marketing': 9, 'Operations': 8,'Technology': 7,'Analytics': 6,'R&D': 5,'Procurement': 4,'Finance': 3,'HR': 2,'Legal': 0})
test['department'] = test['department'].map({'Sales & Marketing': 9,'Operations': 8,'Technology': 7,'Analytics': 6,'R&D': 5,'Procurement': 4,'Finance': 3,'HR': 2, 'Legal': 0})

# %%
train.region.unique()   #34 unique values
# Out:
# array(['region_7', 'region_29', 'region_15', 'region_5', 'region_27',
#        'region_25', 'region_22', 'region_2', 'region_11', 'region_4',
#        'region_31', 'region_18', 'region_21', 'region_23', 'region_26',
#        'region_13', 'region_28', 'region_32', 'region_14', 'region_17',
#        'region_8', 'region_34', 'region_30', 'region_16', 'region_12',
#        'region_10', 'region_24', 'region_6', 'region_33', 'region_1',
#        'region_20', 'region_9', 'region_19', 'region_3'], dtype=object)

# %%
train['region'] = train['region'].map({'region_34': 34, 'region_33': 33, 'region_32': 32, 'region_31': 31,'region_30': 30,'region_29': 29,'region_28': 28,'region_27': 27,'region_26': 26,'region_25': 25,'region_24': 24,'region_23': 23,
                                       'region_22': 22,'region_21': 21,'region_20': 20,'region_19': 19,'region_18': 18,'region_17': 17,'region_16': 16,'region_15': 15, 'region_14': 14,'region_13': 13,'region_12': 12,'region_11': 11,
                                      'region_10': 10,'region_9': 9,'region_8': 8,'region_7': 7, 'region_6': 6,'region_5': 5,'region_4': 4,'region_3': 3,'region_2': 3,'region_1': 1})
test['region'] = test['region'].map({'region_34': 34, 'region_33': 33, 'region_32': 32, 'region_31': 31,'region_30': 30,'region_29': 29,'region_28': 28,'region_27': 27,'region_26': 26,'region_25': 25,'region_24': 24,'region_23': 23,
                                       'region_22': 22,'region_21': 21,'region_20': 20,'region_19': 19,'region_18': 18,'region_17': 17,'region_16': 16,'region_15': 15, 'region_14': 14,'region_13': 13,'region_12': 12,'region_11': 11,
                                      'region_10': 10,'region_9': 9,'region_8': 8,'region_7': 7, 'region_6': 6,'region_5': 5,'region_4': 4,'region_3': 3,'region_2': 3,'region_1': 1})

# %%
train.education.unique()   #3 unique values
# Out:
# array(["Master's & above", "Bachelor's", 'Below Secondary'], dtype=object)

# %%
train.recruitment_channel.unique()   #3 unique values
# Out:
# array(['other', 'sourcing', 'referred'], dtype=object)

# %%
train['gender'] = train['gender'].map({'m': 1, 'f': 0})
test['gender'] = test['gender'].map({'m': 1, 'f': 0})

# %%
train['recruitment_channel'] = train['recruitment_channel'].map({'sourcing': 2, 'referred': 1, 'other': 0})
test['recruitment_channel'] = test['recruitment_channel'].map({'sourcing': 2, 'referred': 1, 'other': 0})

# %%
train['education'] = train['education'].map({"Master's & above": 2, "Bachelor's": 1, 'Below Secondary': 0})
test['education'] = test['education'].map({"Master's & above": 2, "Bachelor's": 1, 'Below Secondary': 0})

# %%
train
# Out:
#       employee_id  department  region  education  gender  recruitment_channel  \
# 0            3057           9       7          2       1                    0
# 1           26295           3      29          1       1                    2
# 2           16310           9      15          1       0                    2
# 3           23364           7       5          1       1                    0
# 4           55642           7      27          1       0                    0
# ...           ...         ...     ...        ...     ...                  ...
# 9663        11685           8      15          1       1                    2
# 9664        14502           7       7          2       1                    0
# 9665         8278           4      13          1       0                    2
# 9666          994           9      14          1       1                    0
# 9667        12592           9      25          2       1                    0
#
#       no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                   1   44                   3.0                  6
# 1                   1   28                   3.0                  2
# 2                   1   38                   3.0                  7
# 3                   1   23                   3.0                  1
# 4                   1   26                   4.0                  2
# ...               ...  ...                   ...                ...
# 9663                1   31                   3.0                  1
# 9664                1   54                   4.0                  7
# 9665                1   30                   4.0                  2
# 9666                1   59                   3.0                 11
# 9667                1   34                   3.0                  7
#
#       awards_won?  avg_training_score  is_promoted
# 0               0                  51            0
# 1               0                  64            0
# 2               0                  49            0
# 3               0                  77            0
# 4               0                  79            0
# ...           ...                 ...          ...
# 9663            0                  56            1
# 9664            0                  81            1
# 9665            0                  86            1
# 9666            0                  65            1
# 9667            0                  60            1
#
# [9668 rows x 13 columns]

# %%
test
# Out:
#        employee_id  department  region  education  gender  \
# 0             8724           7      26          1       1
# 1            74430           2       4          1       0
# 2            72255           9      13          1       1
# 3            38562           4       3          1       0
# 4            64486           3      29          1       1
# ...            ...         ...     ...        ...     ...
# 23485        53478           0       3          0       1
# 23486        25600           7      25          1       1
# 23487        45409           2      16          1       0
# 23488         1186           4      31          1       1
# 23489         5973           7      17          2       1
#
#        recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                        2                1   24                   3.0
# 1                        0                1   31                   3.0
# 2                        0                1   31                   1.0
# 3                        0                3   31                   2.0
# 4                        2                1   30                   4.0
# ...                    ...              ...  ...                   ...
# 23485                    2                1   24                   3.0
# 23486                    2                1   31                   3.0
# 23487                    2                1   26                   4.0
# 23488                    2                3   27                   3.0
# 23489                    0                3   40                   5.0
#
#        length_of_service  awards_won?  avg_training_score
# 0                      1            0                  77
# 1                      5            0                  51
# 2                      4            0                  47
# 3                      9            0                  65
# 4                      7            0                  61
# ...                  ...          ...                 ...
# 23485                  1            0                  61
# 23486                  7            0                  74
# 23487                  4            0                  50
# 23488                  1            0                  70
# 23489                  5            0                  89
#
# [23490 rows x 12 columns]

# %%
train.shape
# Out:
# (9668, 13)

# %%
x = train.iloc[:,1:12].values  #(we took all except on emplayee_id - column 0, and except of the last column - is_promoted)
y = train.iloc[:,12].values

# %%
x
# Out:
# array([[ 9.,  7.,  2., ...,  6.,  0., 51.],
#        [ 3., 29.,  1., ...,  2.,  0., 64.],
#        [ 9., 15.,  1., ...,  7.,  0., 49.],
#        ...,
#        [ 4., 13.,  1., ...,  2.,  0., 86.],
#        [ 9., 14.,  1., ..., 11.,  0., 65.],
#        [ 9., 25.,  2., ...,  7.,  0., 60.]])

# %%
x.shape   #11 features
# Out:
# (9668, 11)

# %%
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
y.shape
# Out:
# (9668,)

# %%
# splitting the training & test sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.3)

# %%
x_train.shape ,x_test.shape, y_train.shape ,y_test.shape
# Out:
# ((6767, 11), (2901, 11), (6767,), (2901,))

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
mc=MinMaxScaler()
x_train1 = mc.fit_transform( x_train)
X_test1 = mc.fit_transform( x_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
# Initialize the model
model=Sequential()

# Build input layer 
model.add(Dense(units=88, activation='relu', input_dim=11))
model.add(Dropout(rate=0.3))

# %%
# Building hidden layer
model.add(Dense(units=44,activation ='relu'))
model.add(Dropout(rate=0.2))

# %%
# Building hidden layer
#model.add(Dense(units=22,activation ='relu'))

# %%
# Building hidden layer
#model.add(Dense(units=11,activation ='relu'))

# %%
#Adding outer layer
model.add(Dense(units=1, activation='sigmoid'))

# %%
# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics = ['accuracy'])

# %%
#model.fit(x_train, y_train, epochs=50, batch_size=1,verbose=1)

from tensorflow.keras.callbacks import EarlyStopping
early_stopping_minitor = EarlyStopping(patience=20)

#train model:   
history = model.fit(x_train, y_train,
 epochs=60,
 batch_size=10,
 #validation_split=0.2,
 callbacks=[early_stopping_minitor])
# Out:
# Epoch 1/60
# 671/677 [============================>.] - ETA: 0s - loss: 0.8794 - accuracy: 0.5401WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 756us/step - loss: 0.8776 - accuracy: 0.5406
# Epoch 2/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6796 - accuracy: 0.5726WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 741us/step - loss: 0.6801 - accuracy: 0.5741
# Epoch 3/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6714 - accuracy: 0.5914WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 739us/step - loss: 0.6700 - accuracy: 0.5921
# Epoch 4/60
# 611/677 [==========================>...] - ETA: 0s - loss: 0.6663 - accuracy: 0.5966WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 743us/step - loss: 0.6680 - accuracy: 0.5938
# Epoch 5/60
# 611/677 [==========================>...] - ETA: 0s - loss: 0.6595 - accuracy: 0.5959WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 743us/step - loss: 0.6598 - accuracy: 0.5972
# Epoch 6/60
# 614/677 [==========================>...] - ETA: 0s - loss: 0.6568 - accuracy: 0.6060WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 741us/step - loss: 0.6568 - accuracy: 0.6044
# Epoch 7/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6530 - accuracy: 0.6077WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 740us/step - loss: 0.6512 - accuracy: 0.6111
# Epoch 8/60
# 611/677 [==========================>...] - ETA: 0s - loss: 0.6430 - accuracy: 0.6295WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 743us/step - loss: 0.6437 - accuracy: 0.6288
# Epoch 9/60
# 614/677 [==========================>...] - ETA: 0s - loss: 0.6365 - accuracy: 0.6279WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 740us/step - loss: 0.6373 - accuracy: 0.6266
# Epoch 10/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.6331 - accuracy: 0.6361WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 742us/step - loss: 0.6345 - accuracy: 0.6362
# Epoch 11/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.6292 - accuracy: 0.6386WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 743us/step - loss: 0.6285 - accuracy: 0.6378
# Epoch 12/60
# 677/677 [==============================] - ETA: 0s - loss: 0.6221 - accuracy: 0.6413WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 747us/step - loss: 0.6221 - accuracy: 0.6413
# Epoch 13/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.6215 - accuracy: 0.6448WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 742us/step - loss: 0.6236 - accuracy: 0.6425
# Epoch 14/60
# 614/677 [==========================>...] - ETA: 0s - loss: 0.6180 - accuracy: 0.6495WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 740us/step - loss: 0.6186 - accuracy: 0.6484
# Epoch 15/60
# 615/677 [==========================>...] - ETA: 0s - loss: 0.6182 - accuracy: 0.6475WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 739us/step - loss: 0.6178 - accuracy: 0.6476
# Epoch 16/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6152 - accuracy: 0.6411WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 741us/step - loss: 0.6153 - accuracy: 0.6431
# Epoch 17/60
# 611/677 [==========================>...] - ETA: 0s - loss: 0.6185 - accuracy: 0.6501WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 743us/step - loss: 0.6179 - accuracy: 0.6514
# Epoch 18/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.6197 - accuracy: 0.6408WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 741us/step - loss: 0.6178 - accuracy: 0.6434
# Epoch 19/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.6153 - accuracy: 0.6523WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 742us/step - loss: 0.6145 - accuracy: 0.6545
# Epoch 20/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6144 - accuracy: 0.6517WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 742us/step - loss: 0.6155 - accuracy: 0.6510
# Epoch 21/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6122 - accuracy: 0.6486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 740us/step - loss: 0.6142 - accuracy: 0.6478
# Epoch 22/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.6088 - accuracy: 0.6547WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 741us/step - loss: 0.6115 - accuracy: 0.6505
# Epoch 23/60
# 611/677 [==========================>...] - ETA: 0s - loss: 0.6112 - accuracy: 0.6502WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 744us/step - loss: 0.6135 - accuracy: 0.6487
# Epoch 24/60
# 674/677 [============================>.] - ETA: 0s - loss: 0.6116 - accuracy: 0.6561WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 751us/step - loss: 0.6116 - accuracy: 0.6564
# Epoch 25/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6102 - accuracy: 0.6535WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 740us/step - loss: 0.6105 - accuracy: 0.6539
# Epoch 26/60
# 676/677 [============================>.] - ETA: 0s - loss: 0.6132 - accuracy: 0.6530WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 746us/step - loss: 0.6132 - accuracy: 0.6530
# Epoch 27/60
# 648/677 [===========================>..] - ETA: 0s - loss: 0.6091 - accuracy: 0.6477WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 777us/step - loss: 0.6102 - accuracy: 0.6464
# Epoch 28/60
# 614/677 [==========================>...] - ETA: 0s - loss: 0.6091 - accuracy: 0.6537WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 740us/step - loss: 0.6085 - accuracy: 0.6538
# Epoch 29/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6108 - accuracy: 0.6538WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 739us/step - loss: 0.6083 - accuracy: 0.6567
# Epoch 30/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6092 - accuracy: 0.6558WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 742us/step - loss: 0.6085 - accuracy: 0.6560
# Epoch 31/60
# 668/677 [============================>.] - ETA: 0s - loss: 0.6087 - accuracy: 0.6490WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 759us/step - loss: 0.6081 - accuracy: 0.6504
# Epoch 32/60
# 666/677 [============================>.] - ETA: 0s - loss: 0.6098 - accuracy: 0.6517WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 759us/step - loss: 0.6100 - accuracy: 0.6515
# Epoch 33/60
# 677/677 [==============================] - ETA: 0s - loss: 0.6083 - accuracy: 0.6505WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 745us/step - loss: 0.6083 - accuracy: 0.6505
# Epoch 34/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.6048 - accuracy: 0.6605WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 741us/step - loss: 0.6053 - accuracy: 0.6607
# Epoch 35/60
# 615/677 [==========================>...] - ETA: 0s - loss: 0.6037 - accuracy: 0.6537WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 739us/step - loss: 0.6045 - accuracy: 0.6566
# Epoch 36/60
# 616/677 [==========================>...] - ETA: 0s - loss: 0.6023 - accuracy: 0.6524WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 738us/step - loss: 0.6035 - accuracy: 0.6518
# Epoch 37/60
# 614/677 [==========================>...] - ETA: 0s - loss: 0.6080 - accuracy: 0.6518WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 740us/step - loss: 0.6068 - accuracy: 0.6523
# Epoch 38/60
# 677/677 [==============================] - ETA: 0s - loss: 0.6011 - accuracy: 0.6541WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 747us/step - loss: 0.6011 - accuracy: 0.6541
# Epoch 39/60
# 611/677 [==========================>...] - ETA: 0s - loss: 0.6030 - accuracy: 0.6520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 744us/step - loss: 0.6053 - accuracy: 0.6510
# Epoch 40/60
# 677/677 [==============================] - ETA: 0s - loss: 0.6027 - accuracy: 0.6603WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 746us/step - loss: 0.6027 - accuracy: 0.6603
# Epoch 41/60
# 677/677 [==============================] - ETA: 0s - loss: 0.6043 - accuracy: 0.6586WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 749us/step - loss: 0.6043 - accuracy: 0.6586
# Epoch 42/60
# 610/677 [==========================>...] - ETA: 0s - loss: 0.6032 - accuracy: 0.6572WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 744us/step - loss: 0.6041 - accuracy: 0.6560
# Epoch 43/60
# 673/677 [============================>.] - ETA: 0s - loss: 0.6056 - accuracy: 0.6495WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 751us/step - loss: 0.6057 - accuracy: 0.6495
# Epoch 44/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.5984 - accuracy: 0.6657WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 741us/step - loss: 0.6004 - accuracy: 0.6626
# Epoch 45/60
# 673/677 [============================>.] - ETA: 0s - loss: 0.5995 - accuracy: 0.6535WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 750us/step - loss: 0.5997 - accuracy: 0.6535
# Epoch 46/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.6053 - accuracy: 0.6531WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 742us/step - loss: 0.6051 - accuracy: 0.6526
# Epoch 47/60
# 610/677 [==========================>...] - ETA: 0s - loss: 0.5980 - accuracy: 0.6595WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 745us/step - loss: 0.5995 - accuracy: 0.6597
# Epoch 48/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.5999 - accuracy: 0.6611WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 742us/step - loss: 0.5999 - accuracy: 0.6586
# Epoch 49/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.6017 - accuracy: 0.6546WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 742us/step - loss: 0.6015 - accuracy: 0.6566
# Epoch 50/60
# 675/677 [============================>.] - ETA: 0s - loss: 0.5962 - accuracy: 0.6640WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 749us/step - loss: 0.5960 - accuracy: 0.6643
# Epoch 51/60
# 652/677 [===========================>..] - ETA: 0s - loss: 0.6012 - accuracy: 0.6609WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 777us/step - loss: 0.6016 - accuracy: 0.6600
# Epoch 52/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.5971 - accuracy: 0.6600WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 743us/step - loss: 0.5969 - accuracy: 0.6606
# Epoch 53/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.5972 - accuracy: 0.6576WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 741us/step - loss: 0.5975 - accuracy: 0.6564
# Epoch 54/60
# 612/677 [==========================>...] - ETA: 0s - loss: 0.5977 - accuracy: 0.6582WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 742us/step - loss: 0.5977 - accuracy: 0.6578
# Epoch 55/60
# 615/677 [==========================>...] - ETA: 0s - loss: 0.5987 - accuracy: 0.6633WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 739us/step - loss: 0.5971 - accuracy: 0.6645
# Epoch 56/60
# 614/677 [==========================>...] - ETA: 0s - loss: 0.6014 - accuracy: 0.6554WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 739us/step - loss: 0.6012 - accuracy: 0.6557
# Epoch 57/60
# 613/677 [==========================>...] - ETA: 0s - loss: 0.5995 - accuracy: 0.6581WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 739us/step - loss: 0.5997 - accuracy: 0.6569
# Epoch 58/60
# 615/677 [==========================>...] - ETA: 0s - loss: 0.5966 - accuracy: 0.6650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 739us/step - loss: 0.5964 - accuracy: 0.6674
# Epoch 59/60
# 677/677 [==============================] - ETA: 0s - loss: 0.5953 - accuracy: 0.6595WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 746us/step - loss: 0.5953 - accuracy: 0.6595
# Epoch 60/60
# 676/677 [============================>.] - ETA: 0s - loss: 0.5977 - accuracy: 0.6607WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 677/677 [==============================] - 1s 748us/step - loss: 0.5976 - accuracy: 0.6606

# %%
# fit model 
#model.fit(x_train,y_train,epochs=150)

# %%
y_pred = model.predict(x_test)
# Out:
# 91/91 [==============================] - 0s 514us/step

# %%
y_pred
# Out:
# array([[0.5400651 ],
#        [0.9373861 ],
#        [0.73094577],
#        ...,
#        [0.55006886],
#        [0.38707504],
#        [0.25418824]], dtype=float32)

# %%
y_pred = y_pred.round()
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[1. 0.]
#  [1. 1.]
#  [1. 1.]
#  ...
#  [1. 1.]
#  [0. 1.]
#  [0. 0.]]

# %%
cmatrix = confusion_matrix(y_test, y_pred)
print(cmatrix)
accuracy_score(y_test, y_pred)
# Out:
# [[1151  340]
#  [ 602  808]]
# 0.6752843846949328

# %%
print('Test accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Test accuracy: 0.6752843846949328

# %%
# Plot loss of train and test set
print(history.history.keys())

#Loss in train and test:
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('model_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy'])
